# %% [markdown]
# https://python.langchain.com/docs/integrations/retrievers/graph_rag/?vector-store=chroma

# %%
from dotenv import load_dotenv
import os 
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

load_dotenv(override=True)
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
MODEL_NAME = os.getenv('MODEL_NAME', 'gpt-4o-mini')
EMB_MODEL_NAME = os.getenv('EMB_MODEL_NAME', 'text-embedding-3-small')
print(OPENAI_API_KEY[:10])
print(MODEL_NAME)

# LangSmith 설정 (.env에서 자동으로 로드됨)
if os.getenv('LANGCHAIN_TRACING_V2') == "true":
    if os.getenv('LANGCHAIN_API_KEY'):
        print('랭스미스로 추적 중입니다 :', os.getenv('LANGCHAIN_API_KEY')[:10])
    else:
        print('랭스미스 키가 확인되지 않았습니다.')

# %%
from langchain_openai import OpenAIEmbeddings

emb = OpenAIEmbeddings(
    model=EMB_MODEL_NAME,
    api_key=OPENAI_API_KEY,
)

# %% [markdown]
# Graph RAG 예제용 “동물(animals)” 데이터셋을 로드합니다.
#
# 이 데이터셋은 각 문서가 짧은 텍스트(예: 동물의 특징, 서식지, 먹이 등)를 담고 있습니다.
#
# 아래 링크에 가면 데이터셋에 대한 간단한 설명이 있습니다.
#
# https://datastax.github.io/graph-rag/reference/graph_rag_example_helpers/
#
# 이 데이터는 graphRAG를 위해 이미 전처리된 Document입니다.
#
# id에는 해당 동물의 이름이 명시되어 있고 metadata에 각각의 속성들이 있어 이 metadata가 지식 그래프 역할을 합니다.
#
# 실제 문장은 page_content에 들어있습니다.

# %%
from graph_rag_example_helpers.datasets.animals import fetch_documents
from langchain_community.vectorstores.utils import filter_complex_metadata
from langchain_graph_retriever.transformers import ShreddingTransformer

raw_docs = fetch_documents()

print(f"데이터 수 : {len(raw_docs)}")
raw_docs[:10]
# Out:
# 데이터 수 : 99
# [Document(id='aardvark', metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords': ['burrowing', 'nocturnal', 'ants', 'savanna'], 'habitat': 'savanna', 'tags': [{'a': 5, 'b': 7}, {'a': 8, 'b': 10}]}, page_content='the aardvark is a nocturnal mammal known for its burrowing habits and long snout used to sniff out ants.'),
#  Document(id='albatross', metadata={'type': 'bird', 'number_of_legs': 2, 'keywords': ['seabird', 'wingspan', 'ocean'], 'habitat': 'marine', 'tags': [{'a': 5, 'b': 8}, {'a': 8, 'b': 10}]}, page_content='the albatross is a large seabird with the longest wingspan of any bird, allowing it to glide effortlessly over oceans.'),
#  Document(id='alligator', metadata={'type': 'reptile', 'number_of_legs': 4, 'keywords': ['reptile', 'jaws', 'wetlands'], 'diet': 'carnivorous', 'nested': {'a': 5}}, page_content='alligators are large reptiles with powerful jaws and are commonly found in freshwater wetlands.'),
#  Document(id='alpaca', metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords': ['wool', 'domesticated', 'friendly'], 'origin': 'south america', 'nested': {'a': 5}}, page_content='alpacas are domesticated mammals valued for their soft wool and friendly demeanor.'),
#  Document(id='ant', metadata={'type': 'insect', 'number_of_legs': 6, 'keywords': ['social', 'colonies', 'strength', 'pollinator'], 'diet': 'omnivorous', 'nested': {'a': 6}}, page_content='ants are social insects that live in colonies and are known for their teamwork and strength.'),
#  Document(id='anteater', metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords': ['ants', 'tongue', 'termites'], 'diet': 'insectivore', 'nested': {'b': 5}}, page_content='anteaters use their long tongues to eat thousands of ants and termites each day.'),
#  Document(id='antelope', metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords': ['graceful', 'herbivore', 'prey'], 'habitat': 'grasslands'}, page_content='antelopes are graceful herbivorous mammals that are often prey for large predators in the wild.'),
#  Document(id='armadillo', metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords': ['protective', 'shell', 'rolling'], 'diet': 'insectivore'}, page_content='armadillos have hard, protective shells and are known for their ability to roll into a ball.'),
#  Document(id='baboon', metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords': ['social', 'primates', 'group'], 'diet': 'omnivorous'}, page_content='baboons are highly social primates with complex group dynamics and strong bonds.'),
#  Document(id='badger', metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords': ['burrowing', 'defense', 'digging'], 'diet': 'omnivorous'}, page_content='badgers are burrowing mammals known for their aggressive defense and digging skills.')]

# %% [markdown]
# "the aardvark is a nocturnal mammal known for its burrowing habits and long snout used to sniff out ants"
# (주머니쥐는 굴을 파는 습관과 개미를 냄새 맡는 데 사용되는 긴 주둥이로 유명한 야행성 포유류입니다.)
#
# 이 문장에서 **문서의 메인 ID(aardvark)**는 중심 개체(노드)를 나타내며,
# **메타데이터(metadata)**에는 그 개체가 가진 **속성**과 **관계**가 적혀있습니다.
#
# 즉, ID와 메타데이터는 문장을 그래프로 변환하기 위한 구조적 관계 정보 역할을 하고 이 정보를 기반으로 GraphRAG은
# "aardvark → nocturnal", "aardvark → burrowing", "aardvark → ants" 와 같은 노드 간 연결(엣지)을 자동으로 구성합니다.
#
#
# ShreddingTransformer는 문서 메타데이터를 “분해(Shredding)”하는 역할을 합니다.
#
# 원래 A와 B가 A(key):B(value)로 되어있었다면 이걸 모두 키로 옮겨 A->B:§로 변경시킵니다.
#
# > §는 transformer가 변경시키면서 기존 value에 있던 위치에 넣는 특수 토큰으로 특별한 의미는 없습니다.
#
# 예시)
#
# id = aardvark, metadata = {keywords': ['burrowing', 'nocturnal', 'ants', 'savanna']}라면 지식그래프에서  ""aardvark_node ---> burrowing, aardvark_node ---> nocturnal,"" 이렇게 연결되어야 하기 때문에
#
# 'keywords→"burrowing"': '§' 이런식으로 모든 리스트를 분해하여 평탄화 시킵니다.

# %%
raw_docs = fetch_documents()
print(f"raw_docs >>".ljust(15), raw_docs[0])

docs = ShreddingTransformer().transform_documents(raw_docs)
print(f"docs >>".ljust(15), docs[0])

animal_docs = filter_complex_metadata(docs) #str, int, float, bool 타입이 아닌 데이터는 제거
print(f"animal_docs >>".ljust(15), animal_docs[0])
# Out:
# raw_docs >>     page_content='the aardvark is a nocturnal mammal known for its burrowing habits and long snout used to sniff out ants.' metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords': ['burrowing', 'nocturnal', 'ants', 'savanna'], 'habitat': 'savanna', 'tags': [{'a': 5, 'b': 7}, {'a': 8, 'b': 10}]}
# docs >>         page_content='the aardvark is a nocturnal mammal known for its burrowing habits and long snout used to sniff out ants.' metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords→"burrowing"': '§', 'keywords→"nocturnal"': '§', 'keywords→"ants"': '§', 'keywords→"savanna"': '§', 'habitat': 'savanna', 'tags→{"a": 5, "b": 7}': '§', 'tags→{"a": 8, "b": 10}': '§', '__shredded_keys': '["keywords", "tags"]'}
# animal_docs >>  page_content='the aardvark is a nocturnal mammal known for its burrowing habits and long snout used to sniff out ants.' metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords→"burrowing"': '§', 'keywords→"nocturnal"': '§', 'keywords→"ants"': '§', 'keywords→"savanna"': '§', 'habitat': 'savanna', 'tags→{"a": 5, "b": 7}': '§', 'tags→{"a": 8, "b": 10}': '§', '__shredded_keys': '["keywords", "tags"]'}

# %%
# 일반적인 벡터 리트리버
from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore.from_documents(
    documents=animal_docs,
    embedding=emb,
)

for data in vector_store.similarity_search("카피바라 근처에서는 어떤 동물을 볼 수 있나요?", k=8):
    print(data)
# Out:
# page_content='caribou, also known as reindeer, are migratory mammals found in arctic regions.' metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords→"migratory"': '§', 'keywords→"arctic"': '§', 'keywords→"herbivore"': '§', 'keywords→"tundra"': '§', 'diet': 'herbivorous', '__shredded_keys': '["keywords"]'}
# page_content='bears are large mammals that can be found across many habitats, from forests to tundras.' metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords→"large"': '§', 'keywords→"habitat"': '§', 'keywords→"omnivore"': '§', 'keywords→"forest-floor"': '§', 'diet': 'omnivorous', 'habitat': 'tundra', '__shredded_keys': '["keywords"]'}
# page_content='antelopes are graceful herbivorous mammals that are often prey for large predators in the wild.' metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords→"graceful"': '§', 'keywords→"herbivore"': '§', 'keywords→"prey"': '§', 'habitat': 'grasslands', '__shredded_keys': '["keywords"]'}
# page_content='coyotes are adaptable mammals known for their distinctive howls and cunning nature.' metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords→"howls"': '§', 'keywords→"adaptable"': '§', 'keywords→"cunning"': '§', 'habitat': 'grasslands', '__shredded_keys': '["keywords"]'}
# page_content='capybaras are the largest rodents in the world and are highly social animals.' metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords→"rodent"': '§', 'keywords→"social"': '§', 'keywords→"largest"': '§', 'habitat': 'wetlands', '__shredded_keys': '["keywords"]'}
# page_content='jackals are carnivorous mammals known for their scavenging and adaptability.' metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords→"scavenger"': '§', 'keywords→"adaptable"': '§', 'keywords→"carnivore"': '§', 'diet': 'omnivorous', '__shredded_keys': '["keywords"]'}
# page_content='ferrets are small, curious mammals often kept as pets for their playful nature.' metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords→"playful"': '§', 'keywords→"curious"': '§', 'keywords→"pet"': '§', 'diet': 'carnivorous', '__shredded_keys': '["keywords"]'}
# page_content='buffalo are large herbivorous mammals known for their horns and grazing habits.' metadata={'type': 'mammal', 'number_of_legs': 4, 'keywords→"herbivore"': '§', 'keywords→"horns"': '§', 'keywords→"grazing"': '§', 'habitat': 'grasslands', '__shredded_keys': '["keywords"]'}

# %% [markdown]
# ## GraphRetriever를 사용해 그래프 검색하기
#
# GraphRetriever는 단순히 의미 유사도(similarity_search)로 검색하는 대신,
#
# “엔티티의 속성(노드)과 관계(엣지)를 따라가며 정보 검색” 을 수행하는 그래프형 RAG 리트리버(retriever)입니다
#
# 가장 중요한건 edges로 어떤 속성끼리 엣지로 연결할지를 결정할 수 있습니다. 즉 내가 선택한 특성으로 그래프를 연결해 노드를 추출할 수 있습니다.
#
# max_depth는 hop이라는 용어로 설명하는데 해당 노드로부터 몇 단계 건너서까지 검색하는지를 결정합니다.
#
# - max_depth = 0 → 자기 자신만
# - max_depth = 1 → 바로 연결된 이웃만
# - max_depth = 2 → 이웃의 이웃까지

# %%
from graph_retriever.strategies import Eager
from langchain_graph_retriever import GraphRetriever

traversal_retriever = GraphRetriever(
    store = vector_store, #일반 벡터 스토어(리트리버)를 사용합니다.
    edges = [("type", "type"), ("habitat", "habitat"), ("number_of_legs", "number_of_legs"), ("diet", "diet"), ("origin", "origin")],
    strategy = Eager(k=8, start_k=15, max_depth=2),  #처음에 15개를 검색하고 그 중 리랭크를 적용해 8개를 최종 결과로 반환합니다.
)

for doc in traversal_retriever.invoke("카피바라 근처에서는 어떤 동물을 볼 수 있나요?"):
    print(doc)
# Out:
# page_content='caribou, also known as reindeer, are migratory mammals found in arctic regions.' metadata={'_depth': 0, '_similarity_score': np.float64(0.3173637597932719), 'type': 'mammal', 'number_of_legs': 4, 'keywords→"migratory"': '§', 'keywords→"arctic"': '§', 'keywords→"herbivore"': '§', 'keywords→"tundra"': '§', 'diet': 'herbivorous', '__shredded_keys': '["keywords"]'}
# page_content='bears are large mammals that can be found across many habitats, from forests to tundras.' metadata={'_depth': 0, '_similarity_score': np.float64(0.3112262209430501), 'type': 'mammal', 'number_of_legs': 4, 'keywords→"large"': '§', 'keywords→"habitat"': '§', 'keywords→"omnivore"': '§', 'keywords→"forest-floor"': '§', 'diet': 'omnivorous', 'habitat': 'tundra', '__shredded_keys': '["keywords"]'}
# page_content='antelopes are graceful herbivorous mammals that are often prey for large predators in the wild.' metadata={'_depth': 0, '_similarity_score': np.float64(0.30539477179838703), 'type': 'mammal', 'number_of_legs': 4, 'keywords→"graceful"': '§', 'keywords→"herbivore"': '§', 'keywords→"prey"': '§', 'habitat': 'grasslands', '__shredded_keys': '["keywords"]'}
# page_content='coyotes are adaptable mammals known for their distinctive howls and cunning nature.' metadata={'_depth': 0, '_similarity_score': np.float64(0.3049246891829087), 'type': 'mammal', 'number_of_legs': 4, 'keywords→"howls"': '§', 'keywords→"adaptable"': '§', 'keywords→"cunning"': '§', 'habitat': 'grasslands', '__shredded_keys': '["keywords"]'}
# page_content='capybaras are the largest rodents in the world and are highly social animals.' metadata={'_depth': 0, '_similarity_score': np.float64(0.28774911800163894), 'type': 'mammal', 'number_of_legs': 4, 'keywords→"rodent"': '§', 'keywords→"social"': '§', 'keywords→"largest"': '§', 'habitat': 'wetlands', '__shredded_keys': '["keywords"]'}
# page_content='jackals are carnivorous mammals known for their scavenging and adaptability.' metadata={'_depth': 0, '_similarity_score': np.float64(0.2822598553778596), 'type': 'mammal', 'number_of_legs': 4, 'keywords→"scavenger"': '§', 'keywords→"adaptable"': '§', 'keywords→"carnivore"': '§', 'diet': 'omnivorous', '__shredded_keys': '["keywords"]'}
# page_content='ferrets are small, curious mammals often kept as pets for their playful nature.' metadata={'_depth': 0, '_similarity_score': np.float64(0.282144720608561), 'type': 'mammal', 'number_of_legs': 4, 'keywords→"playful"': '§', 'keywords→"curious"': '§', 'keywords→"pet"': '§', 'diet': 'carnivorous', '__shredded_keys': '["keywords"]'}
# page_content='buffalo are large herbivorous mammals known for their horns and grazing habits.' metadata={'_depth': 0, '_similarity_score': np.float64(0.27788070253143116), 'type': 'mammal', 'number_of_legs': 4, 'keywords→"herbivore"': '§', 'keywords→"horns"': '§', 'keywords→"grazing"': '§', 'habitat': 'grasslands', '__shredded_keys': '["keywords"]'}

# %% [markdown]
# 아래 코드는 위에서 연결한 그래프를 시각적으로 보기 위한 것으로 RAG와는 관련없고 이해를 돕기 위한 자료입니다.

# %%
import matplotlib.pyplot as plt
import networkx as nx
from collections import Counter
from itertools import combinations
import matplotlib.pyplot as plt
import networkx as nx
def extract_keywords(md: dict):
    kws = []
    for k, v in md.items():
        if v == '§' and k.startswith('keywords→'):
            kw = k.split('→', 1)[1].strip()
            kws.append(kw.strip())
    return kws

def extract_scalar_props(md: dict):
    out = {}
    for k, v in md.items():
        if v != '§':
            out[k] = v
    return out

animal_nodes = []
keyword_nodes = set()
value_nodes = set() 
animal_keywords = {}
animal_props = {}
animal_info = set() 

for d in docs[:5]:
    aid = d.id
    animal_nodes.append(aid)
    kws = extract_keywords(d.metadata)
    props = extract_scalar_props(d.metadata)
    animal_keywords[aid] = kws
    animal_props[aid] = props
    for kw in kws:
        keyword_nodes.add(kw)
    for k, v in props.items():
        if not k.startswith('__'):
            value_nodes.add(str(v))
            animal_info.add(k)
print(animal_info)
G = nx.Graph()

for a in animal_nodes:
    G.add_node(a, kind="animal")
for kw in keyword_nodes:
    G.add_node(kw, kind="keyword")
for val in value_nodes:
    G.add_node(val, kind="value")

for a, kws in animal_keywords.items():
    for kw in kws:
        G.add_edge(a, kw, etype="has_keyword", weight=1.0)

kw_pair_weights = Counter()
for kws in animal_keywords.values():
    for u, v in combinations(sorted(set(kws)), 2):
        kw_pair_weights[(u, v)] += 1
for (u, v), w in kw_pair_weights.items():
    if u in G and v in G:
        if G.has_edge(u, v):
            G[u][v]["weight"] = G[u][v].get("weight", 0) + w
            G[u][v]["etype"] = "kw_cooccur"
        else:
            G.add_edge(u, v, etype="kw_cooccur", weight=float(w))

for a, props in animal_props.items():
    for k, v in props.items():
        if k in animal_info:
            val = str(v)
            if val in G:
                if G.has_edge(a, val):
                    prev = G[a][val].get("label", "")
                    new_label = f"{prev},{k}" if prev else k
                    G[a][val]["label"] = new_label
                else:
                    G.add_edge(a, val, etype="prop", weight=1.0, label=k)

pos = nx.spring_layout(G, seed=42, k=2)

animals = [n for n, d in G.nodes(data=True) if d.get("kind") == "animal"]
keywords = [n for n, d in G.nodes(data=True) if d.get("kind") == "keyword"]
values = [n for n, d in G.nodes(data=True) if d.get("kind") == "value"]

plt.figure(figsize=(11, 9))

nx.draw_networkx_nodes(G, pos, nodelist=animals, node_shape="o", node_size=1200, node_color="#1f78b4")
nx.draw_networkx_nodes(G, pos, nodelist=keywords, node_shape="s", node_size=750, node_color="#9467bd")
nx.draw_networkx_nodes(G, pos, nodelist=values, node_shape="^", node_size=650, node_color="#2ca02c")

edges = G.edges(data=True)
widths = [max(1.0, d.get("weight", 1.0)) for (_, _, d) in edges]
nx.draw_networkx_edges(G, pos, width=widths, arrows=False)

nx.draw_networkx_labels(G, pos, font_size=9)

edge_labels = {(u, v): d["label"] for (u, v, d) in edges if "label" in d}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=9)

plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# {'diet', 'type', 'habitat', 'origin', 'number_of_legs'}

# %% [markdown]
# Exersize) graph 리트리버 옵션을 바꾸면서 결과의 변화를 보기

# %%
standard_retriever = GraphRetriever( 
    store = vector_store,
    edges = [("habitat", "habitat"), ("origin", "origin")], #edge 연결이나 max_depth, start_k등을 변경해가며 결과가 어떻게 변경되는지 실험해봅시다. 
    strategy = Eager(k=10, start_k=15, max_depth=0),
)
for doc in standard_retriever.invoke("카피바라 근처에서는 어떤 다른 동물을 발견할 수 있나요?"):
    print(f"{doc.id}: {doc.page_content}")
# Out:
# coyote: coyotes are adaptable mammals known for their distinctive howls and cunning nature.
# jackal: jackals are carnivorous mammals known for their scavenging and adaptability.
# caribou: caribou, also known as reindeer, are migratory mammals found in arctic regions.
# bear: bears are large mammals that can be found across many habitats, from forests to tundras.
# aardvark: the aardvark is a nocturnal mammal known for its burrowing habits and long snout used to sniff out ants.
# gazelle: gazelles are fast and agile mammals commonly found in grasslands and savannas.
# capybara: capybaras are the largest rodents in the world and are highly social animals.
# ferret: ferrets are small, curious mammals often kept as pets for their playful nature.
# antelope: antelopes are graceful herbivorous mammals that are often prey for large predators in the wild.
# elk: elk are large deer species known for their impressive antlers and bugling calls during mating season.

# %% [markdown]
# ## Graph 리트리버를 사용하여 RAG를 만들어보기
#
# 그래프 리트리버가 이미 만들어졌기 때문에 간단하게 RAG를 만들 수 있습니다.

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    model=MODEL_NAME,
)

prompt = ChatPromptTemplate.from_template(
"""아래 컨텍스트만 근거로 문장으로 답하세요.

##컨텍스트:{context}

##질문: {question}"""
)

def format_docs(docs):
    return "\n\n".join(f"<content>{doc.page_content}</content>" for doc in docs)

chain = (
    {"context": standard_retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)
chain.invoke("카피바라 근처에서 발견할 수 있는 동물은 뭐야?")

# %% [markdown]
# 정작 그러나 결과가 별로 좋지 않습니다. 아래 리트리버를 실행해보면 컨텐츠가 잘 검색 되었는지 의심이 됩니다.

# %%
result = (standard_retriever | format_docs).invoke("카피바라 근처에서 발견할 수 있는 동물은 뭐야?")
print(result)
# Out:
# <content>caribou, also known as reindeer, are migratory mammals found in arctic regions.</content>
#
# <content>the aardvark is a nocturnal mammal known for its burrowing habits and long snout used to sniff out ants.</content>
#
# <content>coyotes are adaptable mammals known for their distinctive howls and cunning nature.</content>
#
# <content>jackals are carnivorous mammals known for their scavenging and adaptability.</content>
#
# <content>gazelles are fast and agile mammals commonly found in grasslands and savannas.</content>
#
# <content>capybaras are the largest rodents in the world and are highly social animals.</content>
#
# <content>antelopes are graceful herbivorous mammals that are often prey for large predators in the wild.</content>
#
# <content>boars are wild relatives of pigs, known for their tough hides and tusks.</content>
#
# <content>foxes are small, agile mammals known for their cunning behavior and bushy tails.</content>
#
# <content>badgers are burrowing mammals known for their aggressive defense and digging skills.</content>

# %% [markdown]
# 영어로 질문을 해 보면 조금 더 나은 결과가 나오는 것을 볼 수 있습니다.

# %%
chain.invoke("what animals could be found near a capybara?")
# Out:
# '카피바라는 습지(wetlands)에 서식하므로, 습지나 그 근처 환경에서 발견될 수 있는 동물이 가능성이 큽니다. 주어진 정보에서는 직접적으로 습지와 동일한 서식지를 가진 다른 동물에 대한 언급이 없으나, 카피바라와 동일한 다리가 4개이고 동일하게 포유류로 분류되는 동물들 중 일부가 습지와 인접한 환경에서 발견될 수 있습니다. 예를 들어, 하마(hippopotamus)는 강가(rivers)와 같이 물가에 서식하는 반면, 카피바라는 습지에 서식합니다. 따라서 하마가 습지 인근에서 발견될 가능성이 있습니다. 반면, 다른 동물들은 사막, 초원, 산림, 북극 등 다른 서식지를 가지고 있어 가까운 서식 환경이 아닙니다.\n\n정리하면, 카피바라가 서식하는 습지 근처에서 하마와 같은 대형 반수생 포유류가 발견될 수 있습니다.'

# %% [markdown]
# 아무래도 데이터가 영어로 되어있어 한글 입력에 대해 약한 성능을 보이는 것 같습니다.

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

translate_for_retrieval = (
    ChatPromptTemplate.from_template(
        """
        사용자의 질문을 RAG를 위한 검색용으로 적합한 간결한 영어 키워드로 번역하세요.
        고유명사는 그대로 유지하세요.
        번역된 질의문만 출력하세요.

        질문: {question}"""
    )
    | llm
    | StrOutputParser()
)

def format_docs(docs):
    return "\n\n".join(f"text: {d.page_content}\nmetadata: {d.metadata}" for d in docs)

chain = (
    {
        "question": RunnablePassthrough(),                                
        "context": translate_for_retrieval | standard_retriever | format_docs, 
    }
    | ChatPromptTemplate.from_template(
        """아래 컨텍스트만 근거로 문장으로 답하세요.
        
        ##컨텍스트:{context}
        
        ##질문: {question}"""
    )
    | llm
    | StrOutputParser()
)
print(translate_for_retrieval.invoke("카피바라 근처에서 발견할 수 있는 동물은 뭐야?"))
chain.invoke("카피바라 근처에서 발견할 수 있는 동물은 뭐야?")
# Out:
# animals near capybara
# '카피바라가 주로 서식하는 습지(wetlands) 근처에서는 하마(hippopotamuses)와 같은 동물을 발견할 수 있습니다.'

# %% [markdown]
# ## Graph Transformers, GraphQAChain를 사용해 Graph RAG 만들기
#
# 앞에서 예시를 통해 그래프의 속성이 meta data로 되어 있을 때 그것을 사용해 그래프로 변경해 그래프 리트리버를 사용하는 방법을 봤습니다.
#
# 이번에는 1) 자연어 문장으로 부터 엔티티를 추출해 metadata로 변경하는 방법과 그렇게 만들어진 graph 정보를 가지고
#
# 2) 랭체인에서 제공하는 graphQA chain을 통해 검색하는 방법을 해보겠습니다.

# %%
import os
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain.chains import GraphQAChain
from langchain_core.documents import Document
from langchain_community.graphs.networkx_graph import NetworkxEntityGraph

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    model=MODEL_NAME,
)

# %%
text = """
Marie Curie, born in 1867, was a Polish and naturalised-French physicist and chemist who conducted pioneering research on radioactivity.
She was the first woman to win a Nobel Prize, the first person to win a Nobel Prize twice, and the only person to win a Nobel Prize in two scientific fields.
Her husband, Pierre Curie, was a co-winner of her first Nobel Prize, making them the first-ever married couple to win the Nobel Prize and launching the Curie family legacy of five Nobel Prizes.
She was, in 1906, the first woman to become a professor at the University of Paris. 
"""

# %% [markdown]
# 자연어에서 엔티티를 추출해 그래프로 바꾸는 역할은 LLMGraphTransformer가 합니다.
#
# 텍스트를 분석해서 지식 그래프(knowledge graph) 구조로 바꿉니다.

# %%
documents = [Document(page_content=text)]
llm_transformer = LLMGraphTransformer(llm=llm)
graph_documents = llm_transformer.convert_to_graph_documents(documents)

# %%
for node in graph_documents[0].nodes:
    print(node)

print('==============================')

for edge in graph_documents[0].relationships:
    print(edge)
# Out:
# id='Marie Curie' type='Person' properties={}
# id='1867' type='Year' properties={}
# id='Poland' type='Country' properties={}
# id='France' type='Country' properties={}
# id='Physicist' type='Occupation' properties={}
# id='Chemist' type='Occupation' properties={}
# id='Radioactivity' type='Concept' properties={}
# id='Nobel Prize' type='Award' properties={}
# id='Pierre Curie' type='Person' properties={}
# id='Curie Family' type='Family' properties={}
# id='Five Nobel Prizes' type='Concept' properties={}
# id='University Of Paris' type='Organization' properties={}
# id='1906' type='Year' properties={}
# id='First Woman To Win A Nobel Prize' type='Status' properties={}
# id='First Person To Win A Nobel Prize Twice' type='Status' properties={}
# id='Only Person To Win A Nobel Prize In Two Scientific Fields' type='Status' properties={}
# id='First-Ever Married Couple To Win The Nobel Prize' type='Status' properties={}
# ==============================
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='1867', type='Year', properties={}) type='BORN' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='Poland', type='Country', properties={}) type='NATIONALITY' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='France', type='Country', properties={}) type='NATIONALITY' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='Physicist', type='Occupation', properties={}) type='OCCUPATION' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='Chemist', type='Occupation', properties={}) type='OCCUPATION' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='Radioactivity', type='Concept', properties={}) type='RESEARCH' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='Nobel Prize', type='Award', properties={}) type='WON_AWARD' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='Nobel Prize', type='Award', properties={}) type='WON_AWARD' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='First Woman To Win A Nobel Prize', type='Status', properties={}) type='STATUS' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='First Person To Win A Nobel Prize Twice', type='Status', properties={}) type='STATUS' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='Only Person To Win A Nobel Prize In Two Scientific Fields', type='Status', properties={}) type='STATUS' properties={}
# source=Node(id='Pierre Curie', type='Person', properties={}) target=Node(id='Nobel Prize', type='Award', properties={}) type='WON_AWARD' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='Pierre Curie', type='Person', properties={}) type='SPOUSE' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='First-Ever Married Couple To Win The Nobel Prize', type='Status', properties={}) type='STATUS' properties={}
# source=Node(id='Pierre Curie', type='Person', properties={}) target=Node(id='First-Ever Married Couple To Win The Nobel Prize', type='Status', properties={}) type='STATUS' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='University Of Paris', type='Organization', properties={}) type='PROFESSOR' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='1906', type='Year', properties={}) type='OCCURRED_IN' properties={}
# source=Node(id='Marie Curie', type='Person', properties={}) target=Node(id='Curie Family', type='Family', properties={}) type='MEMBER_OF' properties={}
# source=Node(id='Pierre Curie', type='Person', properties={}) target=Node(id='Curie Family', type='Family', properties={}) type='MEMBER_OF' properties={}
# source=Node(id='Curie Family', type='Family', properties={}) target=Node(id='Five Nobel Prizes', type='Concept', properties={}) type='HAS_LEGACY' properties={}

# %%
import matplotlib.pyplot as plt
import networkx as nx

def graphdocument_to_nx(graph_document):
    G = nx.DiGraph()

    for n in graph_document.nodes:
        G.add_node(n.id, type=getattr(n, "type", None), **(getattr(n, "properties", {}) or {}))

    for r in graph_document.relationships:
        src = getattr(r.source, "id", r.source)
        dst = getattr(r.target, "id", r.target)
        rel_type = getattr(r, "type", None)
        G.add_edge(src, dst, type=rel_type)
    return G

gd = graph_documents[0]
G = graphdocument_to_nx(gd)

plt.figure(figsize=(11, 9))
pos = nx.spring_layout(G, seed=42)      
nx.draw_networkx_nodes(G, pos, node_size=800)
nx.draw_networkx_edges(G, pos, arrows=True, arrowstyle='-|>', arrowsize=12)
nx.draw_networkx_labels(G, pos, font_size=8)

edge_labels = nx.get_edge_attributes(G, 'type')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=7)

plt.axis('off')
plt.title("GraphDocument Visualization")
plt.show()

# %% [markdown]
# 그러나 어떤 속성이 생길지 알 수 없고 불필요하게 많은 속성은 오히려 성능을 나쁘게 만들 수 있습니다.
#
# 사용하고자 하는 상황에 맞게 그래프의 노드와 엣지의 속성을 제한해줍니다.

# %%
llm_transformer_filtered = LLMGraphTransformer(
    llm=llm,
    allowed_nodes=["Person", "Country", "Organization"],
    allowed_relationships=["NATIONALITY", "LOCATED_IN", "WORKED_AT", "SPOUSE"],
)
graph_documents_filtered = llm_transformer_filtered.convert_to_graph_documents(
    documents
)

# %%
gd = graph_documents_filtered[0]
G = graphdocument_to_nx(gd)

plt.figure(figsize=(11, 9))
pos = nx.spring_layout(G, seed=42)      
nx.draw_networkx_nodes(G, pos, node_size=800)
nx.draw_networkx_edges(G, pos, arrows=True, arrowstyle='-|>', arrowsize=12)
nx.draw_networkx_labels(G, pos, font_size=8)

edge_labels = nx.get_edge_attributes(G, 'type')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=7)

plt.axis('off')
plt.title("GraphDocument Visualization")
plt.show()

# %% [markdown]
# 위의 작업은 엔티티가 추출된 Document입니다.
# 이것을 실제로 그래프로 만들어주기 위해 NetworkxEntityGraph를 사용합니다.

# %%
graph = NetworkxEntityGraph()

for node in graph_documents_filtered[0].nodes:
    graph.add_node(node.id) #노드를 추가

for edge in graph_documents_filtered[0].relationships:
    graph._graph.add_edge(
            edge.source.id, #소스 노드의 ID
            edge.target.id, #타겟 노드의 ID
            relation=edge.type, #엣지의 타입
        )

# %% [markdown]
# 랭체인은 그래프 검색을 위한 GraphQAChain을 제공합니다.
#
# 1. 사용자의 질문을 입력받음 (예: “Marie Curie가가 누구야?”)
# 2. LLM이 질문에서 엔티티 추출 (→ “Marie Curie”)
# 3. 그래프에서 해당 노드의 주변 관계 검색
# 4. 관련 트리플(context)들을 LLM에 전달 - (Marie Curie, SPOUSE, Pierre Curie)
# 5. LLM이 context 기반으로 최종 답변 생성

# %%
chain = GraphQAChain.from_llm(
    llm=llm, 
    graph=graph, 
    verbose=True
)

# %%
question = "Marie Curie가 누구야?"
chain.run(question)
# Out:
# > Entering new GraphQAChain chain...
# Entities Extracted:
# Marie Curie
# Full Context:
# Marie Curie NATIONALITY Poland
# Marie Curie NATIONALITY France
# Marie Curie WORKED_AT University Of Paris
# Marie Curie SPOUSE Pierre Curie
#
# > Finished chain.
# 'Marie Curie는 폴란드와 프랑스 국적을 가진 인물로, 파리 대학(University of Paris)에서 일했으며 배우자는 피에르 퀴리(Pierre Curie)입니다.'

# %% [markdown]
# 하나의 코드로 묶어서 봅시다.

# %%
from langchain_core.documents import Document
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain.chains import GraphQAChain
from langchain.graphs import NetworkxEntityGraph

text = """
Marie Curie, born in 1867, was a Polish and naturalised-French physicist and chemist who conducted pioneering research on radioactivity.
She was the first woman to win a Nobel Prize, the first person to win a Nobel Prize twice, and the only person to win a Nobel Prize in two scientific fields.
Her husband, Pierre Curie, was a co-winner of her first Nobel Prize, making them the first-ever married couple to win the Nobel Prize and launching the Curie family legacy of five Nobel Prizes.
She was, in 1906, the first woman to become a professor at the University of Paris. 
"""

documents = [Document(page_content=text)]
llm_transformer = LLMGraphTransformer(llm=llm)
graph_documents = llm_transformer.convert_to_graph_documents(documents)

llm_transformer_filtered = LLMGraphTransformer(
    llm=llm,
    allowed_nodes=["Person", "Country", "Organization"],
    allowed_relationships=["NATIONALITY", "LOCATED_IN", "WORKED_AT", "SPOUSE"],
)
graph_documents_filtered = llm_transformer_filtered.convert_to_graph_documents(
    documents
)

graph = NetworkxEntityGraph()

for node in graph_documents_filtered[0].nodes:
    graph.add_node(node.id)

for edge in graph_documents_filtered[0].relationships:
    graph._graph.add_edge(
            edge.source.id,
            edge.target.id,
            relation=edge.type,
        )

chain = GraphQAChain.from_llm(
    llm=llm, 
    graph=graph, 
    verbose=True
)

chain.run("Marie Curie가 누구야?")
# Out:
# /tmp/ipykernel_109359/1821993952.py:44: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   chain.run("Marie Curie가 누구야?")
# > Entering new GraphQAChain chain...
# Entities Extracted:
# Marie Curie
# Full Context:
# Marie Curie NATIONALITY Poland
# Marie Curie NATIONALITY France
# Marie Curie WORKED_AT University Of Paris
#
# > Finished chain.
# 'Marie Curie는 폴란드와 프랑스 국적을 가진 과학자로, 파리 대학(University Of Paris)에서 근무했습니다.'

# %% [markdown]
# ## graph RAG를 사용한 기업 정보 답변기

# %% [markdown]
# 위키피디아 https://en.wikipedia.org/wiki/Portal:Companies/Index_by_industry 기업 정보 페이지에 들어가면 다양한 분야의 기업들이 정리되어 있습니다.
#
# 여기에서 통신(Telecommunications) 관련 기업들의 정보를 모아 답변해주는 RAG를 만들어보겠습니다.

# %%
import os
from urllib.parse import quote

from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter, MarkdownHeaderTextSplitter

from langchain_community.document_loaders import AsyncHtmlLoader
from langchain_community.document_transformers import Html2TextTransformer

from langchain_community.document_loaders import WikipediaLoader

from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain.graphs import NetworkxEntityGraph
from langchain.chains.graph_qa.base import GraphQAChain

titles = [ #양이 많아 몇 개만 추려서 사용합니다.
    "KT_Corporation", 
    "AT&T", "Avaya", "Qwest", "Sprint_Corporation"
    "China_Mobile", "China_Telecom",
    "KDDI", "Nippon_Telegraph_and_Telephone",
]

def build_urls_from_titles(ts):
    return [f"https://en.wikipedia.org/wiki/{quote(t.replace(' ', '_'))}" for t in ts]

def load_docs_html(urls):
    loader = AsyncHtmlLoader(urls, verify_ssl=True, encoding="utf-8")
    html_docs = loader.load()
    html2text = Html2TextTransformer()
    text_docs = html2text.transform_documents(html_docs)
    return text_docs

def load_docs_wikipedia_api(ts):
    out = []
    for t in ts:
        try:
            w = WikipediaLoader(query=t, load_max_docs=1, lang="en")
            d = w.load()
            out.extend(d)
        except Exception as e:
            print(f"[warn] WikipediaLoader failed for {t}: {e}")
    return out

urls = build_urls_from_titles(titles)
docs = load_docs_html(urls)

docs = [d if isinstance(d, Document) else Document(page_content=str(d)) for d in docs] #<-- 문자열이면 Document로 변환해주기

splitter = CharacterTextSplitter(
    chunk_size=250, chunk_overlap=20,
)
splits = splitter.split_documents(docs)
print(f"[info] loaded docs: {len(docs)}, splits: {len(splits)}")
# Out:
# Fetching pages: 100%|##########| 8/8 [00:01<00:00,  5.20it/s]
# Created a chunk of size 690, which is longer than the specified 250
# Created a chunk of size 949, which is longer than the specified 250
# Created a chunk of size 1523, which is longer than the specified 250
# Created a chunk of size 532, which is longer than the specified 250
# Created a chunk of size 1010, which is longer than the specified 250
# Created a chunk of size 1222, which is longer than the specified 250
# Created a chunk of size 1711, which is longer than the specified 250
# Created a chunk of size 4007, which is longer than the specified 250
# Created a chunk of size 802, which is longer than the specified 250
# Created a chunk of size 806, which is longer than the specified 250
# Created a chunk of size 252, which is longer than the specified 250
# Created a chunk of size 347, which is longer than the specified 250
# Created a chunk of size 342, which is longer than the specified 250
# Created a chunk of size 255, which is longer than the specified 250
# Created a chunk of size 779, which is longer than the specified 250
# Created a chunk of size 277, which is longer than the specified 250
# Created a chunk of size 474, which is longer than the specified 250
# Created a chunk of size 359, which is longer than the specified 250
# Created a chunk of size 415, which is longer than the specified 250
# Created a chunk of size 736, which is longer than the specified 250
# Created a chunk of size 380, which is longer than the specified 250
# Created a chunk of size 317, which is longer than the specified 250
# Created a chunk of size 603, which is longer than the specified 250
# Created a chunk of size 870, which is longer than the specified 250
# Created a chunk of size 272, which is longer than the specified 250
# Created a chunk of size 345, which is longer than the specified 250
# Created a chunk of size 315, which is longer than the specified 250
# Created a chunk of size 10459, which is longer than the specified 250
# Created a chunk of size 1126, which is longer than the specified 250
# Created a chunk of size 760, which is longer than the specified 250
# Created a chunk of size 448, which is longer than the specified 250
# Created a chunk of size 394, which is longer than the specified 250
# Created a chunk of size 513, which is longer than the specified 250
# Created a chunk of size 449, which is longer than the specified 250
# Created a chunk of size 264, which is longer than the specified 250
# Created a chunk of size 358, which is longer than the specified 250
# Created a chunk of size 334, which is longer than the specified 250
# Created a chunk of size 1035, which is longer than the specified 250
# Created a chunk of size 1170, which is longer than the specified 250
# Created a chunk of size 313, which is longer than the specified 250
# Created a chunk of size 703, which is longer than the specified 250
# Created a chunk of size 347, which is longer than the specified 250
# Created a chunk of size 857, which is longer than the specified 250
# Created a chunk of size 253, which is longer than the specified 250
# Created a chunk of size 682, which is longer than the specified 250
# Created a chunk of size 1128, which is longer than the specified 250
# Created a chunk of size 624, which is longer than the specified 250
# Created a chunk of size 545, which is longer than the specified 250
# Created a chunk of size 407, which is longer than the specified 250
# Created a chunk of size 864, which is longer than the specified 250
# Created a chunk of size 415, which is longer than the specified 250
# Created a chunk of size 861, which is longer than the specified 250
# Created a chunk of size 533, which is longer than the specified 250
# Created a chunk of size 411, which is longer than the specified 250
# Created a chunk of size 693, which is longer than the specified 250
# Created a chunk of size 510, which is longer than the specified 250
# Created a chunk of size 298, which is longer than the specified 250
# Created a chunk of size 290, which is longer than the specified 250
# Created a chunk of size 371, which is longer than the specified 250
# Created a chunk of size 309, which is longer than the specified 250
# Created a chunk of size 331, which is longer than the specified 250
# Created a chunk of size 301, which is longer than the specified 250
# Created a chunk of size 256, which is longer than the specified 250
# Created a chunk of size 464, which is longer than the specified 250
# Created a chunk of size 1178, which is longer than the specified 250
# Created a chunk of size 289, which is longer than the specified 250
# Created a chunk of size 415, which is longer than the specified 250
# Created a chunk of size 292, which is longer than the specified 250
# Created a chunk of size 1309, which is longer than the specified 250
# Created a chunk of size 434, which is longer than the specified 250
# Created a chunk of size 581, which is longer than the specified 250
# Created a chunk of size 928, which is longer than the specified 250
# Created a chunk of size 1101, which is longer than the specified 250
# Created a chunk of size 1252, which is longer than the specified 250
# Created a chunk of size 269, which is longer than the specified 250
# Created a chunk of size 282, which is longer than the specified 250
# Created a chunk of size 1043, which is longer than the specified 250
# Created a chunk of size 341, which is longer than the specified 250
# Created a chunk of size 266, which is longer than the specified 250
# Created a chunk of size 457, which is longer than the specified 250
# Created a chunk of size 662, which is longer than the specified 250
# Created a chunk of size 698, which is longer than the specified 250
# Created a chunk of size 549, which is longer than the specified 250
# Created a chunk of size 354, which is longer than the specified 250
# Created a chunk of size 338, which is longer than the specified 250
# Created a chunk of size 289, which is longer than the specified 250
# Created a chunk of size 519, which is longer than the specified 250
# Created a chunk of size 336, which is longer than the specified 250
# Created a chunk of size 578, which is longer than the specified 250
# Created a chunk of size 387, which is longer than the specified 250
# Created a chunk of size 741, which is longer than the specified 250
# Created a chunk of size 335, which is longer than the specified 250
# Created a chunk of size 383, which is longer than the specified 250
# Created a chunk of size 1081, which is longer than the specified 250
# Created a chunk of size 591, which is longer than the specified 250
# Created a chunk of size 649, which is longer than the specified 250
# Created a chunk of size 266, which is longer than the specified 250
# Created a chunk of size 653, which is longer than the specified 250
# Created a chunk of size 423, which is longer than the specified 250
# Created a chunk of size 1037, which is longer than the specified 250
# Created a chunk of size 667, which is longer than the specified 250
# Created a chunk of size 448, which is longer than the specified 250
# Created a chunk of size 1287, which is longer than the specified 250
# Created a chunk of size 526, which is longer than the specified 250
# Created a chunk of size 1188, which is longer than the specified 250
# Created a chunk of size 604, which is longer than the specified 250
# Created a chunk of size 51052, which is longer than the specified 250
# Created a chunk of size 269, which is longer than the specified 250
# Created a chunk of size 396, which is longer than the specified 250
# Created a chunk of size 558, which is longer than the specified 250
# Created a chunk of size 530, which is longer than the specified 250
# Created a chunk of size 341, which is longer than the specified 250
# Created a chunk of size 342, which is longer than the specified 250
# Created a chunk of size 711, which is longer than the specified 250
# Created a chunk of size 307, which is longer than the specified 250
# Created a chunk of size 1032, which is longer than the specified 250
# Created a chunk of size 376, which is longer than the specified 250
# Created a chunk of size 652, which is longer than the specified 250
# Created a chunk of size 1126, which is longer than the specified 250
# Created a chunk of size 544, which is longer than the specified 250
# Created a chunk of size 483, which is longer than the specified 250
# Created a chunk of size 261, which is longer than the specified 250
# Created a chunk of size 251, which is longer than the specified 250
# Created a chunk of size 495, which is longer than the specified 250
# Created a chunk of size 1108, which is longer than the specified 250
# Created a chunk of size 346, which is longer than the specified 250
# Created a chunk of size 429, which is longer than the specified 250
# Created a chunk of size 866, which is longer than the specified 250
# Created a chunk of size 485, which is longer than the specified 250
# Created a chunk of size 315, which is longer than the specified 250
# Created a chunk of size 290, which is longer than the specified 250
# Created a chunk of size 818, which is longer than the specified 250
# Created a chunk of size 714, which is longer than the specified 250
# Created a chunk of size 295, which is longer than the specified 250
# Created a chunk of size 340, which is longer than the specified 250
# Created a chunk of size 5038, which is longer than the specified 250
# Created a chunk of size 456, which is longer than the specified 250
# Created a chunk of size 284, which is longer than the specified 250
# Created a chunk of size 1063, which is longer than the specified 250
# Created a chunk of size 590, which is longer than the specified 250
# Created a chunk of size 348, which is longer than the specified 250
# Created a chunk of size 1189, which is longer than the specified 250
# Created a chunk of size 1084, which is longer than the specified 250
# Created a chunk of size 959, which is longer than the specified 250
# Created a chunk of size 700, which is longer than the specified 250
# Created a chunk of size 598, which is longer than the specified 250
# Created a chunk of size 367, which is longer than the specified 250
# Created a chunk of size 493, which is longer than the specified 250
# Created a chunk of size 443, which is longer than the specified 250
# Created a chunk of size 338, which is longer than the specified 250
# Created a chunk of size 748, which is longer than the specified 250
# Created a chunk of size 884, which is longer than the specified 250
# Created a chunk of size 523, which is longer than the specified 250
# Created a chunk of size 357, which is longer than the specified 250
# Created a chunk of size 647, which is longer than the specified 250
# Created a chunk of size 397, which is longer than the specified 250
# Created a chunk of size 562, which is longer than the specified 250
# Created a chunk of size 1252, which is longer than the specified 250
# Created a chunk of size 672, which is longer than the specified 250
# Created a chunk of size 4499, which is longer than the specified 250
# Created a chunk of size 326, which is longer than the specified 250
# Created a chunk of size 476, which is longer than the specified 250
# Created a chunk of size 304, which is longer than the specified 250
# Created a chunk of size 291, which is longer than the specified 250
# Created a chunk of size 285, which is longer than the specified 250
# Created a chunk of size 696, which is longer than the specified 250
# Created a chunk of size 290, which is longer than the specified 250
# Created a chunk of size 1455, which is longer than the specified 250
# Created a chunk of size 770, which is longer than the specified 250
# Created a chunk of size 304, which is longer than the specified 250
# Created a chunk of size 405, which is longer than the specified 250
# Created a chunk of size 476, which is longer than the specified 250
# Created a chunk of size 304, which is longer than the specified 250
# Created a chunk of size 349, which is longer than the specified 250
# Created a chunk of size 286, which is longer than the specified 250
# Created a chunk of size 324, which is longer than the specified 250
# Created a chunk of size 441, which is longer than the specified 250
# Created a chunk of size 493, which is longer than the specified 250
# Created a chunk of size 407, which is longer than the specified 250
# Created a chunk of size 773, which is longer than the specified 250
# Created a chunk of size 430, which is longer than the specified 250
# Created a chunk of size 320, which is longer than the specified 250
# Created a chunk of size 308, which is longer than the specified 250
# Created a chunk of size 473, which is longer than the specified 250
# Created a chunk of size 746, which is longer than the specified 250
# Created a chunk of size 391, which is longer than the specified 250
# Created a chunk of size 445, which is longer than the specified 250
# Created a chunk of size 257, which is longer than the specified 250
# Created a chunk of size 1094, which is longer than the specified 250
# Created a chunk of size 763, which is longer than the specified 250
# Created a chunk of size 7198, which is longer than the specified 250
# Created a chunk of size 1126, which is longer than the specified 250
# Created a chunk of size 1035, which is longer than the specified 250
# Created a chunk of size 1170, which is longer than the specified 250
# Created a chunk of size 1464, which is longer than the specified 250
# Created a chunk of size 498, which is longer than the specified 250
# Created a chunk of size 817, which is longer than the specified 250
# Created a chunk of size 346, which is longer than the specified 250
# Created a chunk of size 336, which is longer than the specified 250
# Created a chunk of size 1114, which is longer than the specified 250
# Created a chunk of size 1172, which is longer than the specified 250
# Created a chunk of size 694, which is longer than the specified 250
# Created a chunk of size 568, which is longer than the specified 250
# Created a chunk of size 399, which is longer than the specified 250
# Created a chunk of size 256, which is longer than the specified 250
# Created a chunk of size 316, which is longer than the specified 250
# Created a chunk of size 605, which is longer than the specified 250
# Created a chunk of size 299, which is longer than the specified 250
# Created a chunk of size 255, which is longer than the specified 250
# Created a chunk of size 1796, which is longer than the specified 250
# Created a chunk of size 412, which is longer than the specified 250
# Created a chunk of size 1083, which is longer than the specified 250
# Created a chunk of size 3307, which is longer than the specified 250
# Created a chunk of size 383, which is longer than the specified 250
# Created a chunk of size 334, which is longer than the specified 250
# Created a chunk of size 1126, which is longer than the specified 250
# Created a chunk of size 486, which is longer than the specified 250
# Created a chunk of size 424, which is longer than the specified 250
# Created a chunk of size 347, which is longer than the specified 250
# Created a chunk of size 331, which is longer than the specified 250
# Created a chunk of size 1053, which is longer than the specified 250
# Created a chunk of size 374, which is longer than the specified 250
# Created a chunk of size 332, which is longer than the specified 250
# Created a chunk of size 726, which is longer than the specified 250
# Created a chunk of size 834, which is longer than the specified 250
# Created a chunk of size 629, which is longer than the specified 250
# Created a chunk of size 332, which is longer than the specified 250
# Created a chunk of size 503, which is longer than the specified 250
# Created a chunk of size 687, which is longer than the specified 250
# Created a chunk of size 302, which is longer than the specified 250
# Created a chunk of size 1685, which is longer than the specified 250
# Created a chunk of size 371, which is longer than the specified 250
# Created a chunk of size 1034, which is longer than the specified 250
# Created a chunk of size 267, which is longer than the specified 250
# Created a chunk of size 451, which is longer than the specified 250
# Created a chunk of size 327, which is longer than the specified 250
# Created a chunk of size 2974, which is longer than the specified 250
# Created a chunk of size 412, which is longer than the specified 250
# Created a chunk of size 1083, which is longer than the specified 250
# Created a chunk of size 3307, which is longer than the specified 250
# Created a chunk of size 1035, which is longer than the specified 250
# Created a chunk of size 1170, which is longer than the specified 250
# Created a chunk of size 1126, which is longer than the specified 250
# Created a chunk of size 666, which is longer than the specified 250
# Created a chunk of size 334, which is longer than the specified 250
# Created a chunk of size 346, which is longer than the specified 250
# [info] loaded docs: 8, splits: 656

# %%
transformer = LLMGraphTransformer(
    llm=llm,
    # allowed_nodes=[],
    # allowed_relationships=[],
)

import asyncio
from itertools import islice

def batched(iterable, n):
    it = iter(iterable)
    while True:
        chunk = list(islice(it, n))
        if not chunk: break
        yield chunk

BATCH_SIZE = 16      # 한 요청당 split 개수
MAX_CONCURRENCY = 4  # 동시에 날릴 배치 개수(요금/TPM 제한에 맞춰)

async def process_batch(batch):
    return await transformer.aconvert_to_graph_documents(batch)

from tqdm import tqdm
async def main_async():
    tasks, results = [], []
    sem = asyncio.Semaphore(MAX_CONCURRENCY)

    async def worker(b):
        async with sem:
            return await process_batch(b)

    batches = list(batched(splits, BATCH_SIZE))
    for b in batches:
        tasks.append(asyncio.create_task(worker(b)))

    for i, t in tqdm(enumerate(asyncio.as_completed(tasks), 1), total=len(batches)):
        gds = await t
        results.extend(gds)

    return results

all_graph_docs = await main_async()

for doc in all_graph_docs[:10]:
    for node in doc.nodes:
        print(node)

print('==============================')

for doc in all_graph_docs[:10]:
    for edge in doc.relationships:
        print(edge)
# Out:
# 100%|██████████| 41/41 [03:11<00:00,  4.68s/it]
# id='Kt' type='Organization' properties={}
# id='East Telecom' type='Organization' properties={}
# id='Uzbekistan' type='Country' properties={}
# id='Super Imax' type='Organization' properties={}
# id='Kt Japan Co., Ltd.' type='Organization' properties={}
# id='Kt' type='Organization' properties={}
# id='International Network Infrastructure Business' type='Business operation' properties={}
# id='Local Network Infrastructure Business' type='Business operation' properties={}
# id='Data Center Business' type='Business operation' properties={}
# id='Housing' type='Business operation' properties={}
# id='Cloud Services' type='Business operation' properties={}
# id='Roaming Business' type='Business operation' properties={}
# id='Data Roaming Business' type='Business operation' properties={}
# id='Sim Card Sales' type='Business operation' properties={}
# id='Overseas Information And Communications Research' type='Business operation' properties={}
# id='Kt Sports' type='Organization' properties={}
# id='Kt Sports' type='Organization' properties={}
# id='Kt Corporation' type='Organization' properties={}
# id='Ktf' type='Organization' properties={}
# id='Suwon' type='Place' properties={}
# id='Baseball' type='Sport' properties={}
# id='Basketball' type='Sport' properties={}
# id='Esports' type='Sport' properties={}
# id='Shooting' type='Sport' properties={}
# id='Field Hockey' type='Sport' properties={}
# id='Sports' type='Concept' properties={}
# id='Suwon Kt Sonicboom' type='Sports team' properties={}
# id="Men'S Basketball" type='Sports category' properties={}
# id='Suwon' type='Location' properties={}
# id='Kt Wiz' type='Sports team' properties={}
# id='Baseball' type='Sports category' properties={}
# id='Kt Rolster' type='Sports team' properties={}
# id='Starcraft Ii' type='Sports category' properties={}
# id='League Of Legends' type='Sports category' properties={}
# id='Professional Gaming Teams' type='Category' properties={}
# id='Seoul' type='Location' properties={}
# id='Kt Shooting Team' type='Sports team' properties={}
# id='Sports Shooting' type='Sports category' properties={}
# id='Hwaseong' type='Location' properties={}
# id='Kt Hockey Team' type='Sports team' properties={}
# id="Women'S Field Hockey" type='Sports category' properties={}
# id='Seongnam' type='Location' properties={}
# id='Kt' type='Organization' properties={}
# id='South Korea National Football Team' type='Organization' properties={}
# id='Lpga Of Korea Tour Golfers' type='Group' properties={}
# id='2002 Fifa World Cup' type='Event' properties={}
# id='Korea' type='Location' properties={}
# id='Japan' type='Location' properties={}
# id='Kt Corporation' type='Organization' properties={}
# id='Sk Telecom' type='Organization' properties={}
# id='Telecommunications Derby' type='Event' properties={}
# id='Esports' type='Activity' properties={}
# id="Men'S Basketball" type='Activity' properties={}
# id='Sk Wyverns' type='Organization' properties={}
# id='Kt Wiz' type='Organization' properties={}
# id='Smart Grid Investment' type='Concept' properties={}
# id='Kt' type='Organization' properties={}
# id='Jeju Smart Place Test Bed Project' type='Project' properties={}
# id="Korea'S Ministry Of Trade, Industry And Energy" type='Organization' properties={}
# id="6,000 Households In Jeju Island'S Gujwa-Eup Area" type='Location' properties={}
# id='May 2009' type='Date' properties={}
# id='May 2013' type='Date' properties={}
# id='Kt Consortium' type='Organization' properties={}
# id='Samsung Sdi' type='Organization' properties={}
# id='Hyosung' type='Organization' properties={}
# id='Samsung Electronics' type='Organization' properties={}
# id='Renewable Energy Sources' type='Concept' properties={}
# id='Energy Storage Devices' type='Concept' properties={}
# id='Integrated Energy Management Service' type='Concept' properties={}
# id='Efficient Energy Usage' type='Concept' properties={}
# id='Kt Internet Slowdown Incident' type='Event' properties={}
# id='April 17, 2021' type='Date' properties={}
# id='10-Gigabit Internet Plan' type='Concept' properties={}
# id='Youtuber It-Seop' type='Person' properties={}
# id='100 Megabit' type='Concept' properties={}
# id='Speed Test Data' type='Concept' properties={}
# id='Video' type='Concept' properties={}
# id='Controversy' type='Concept' properties={}
# id='Kt Users' type='Group' properties={}
# id='April 19, 2021' type='Date' properties={}
# id='Kt' type='Organization' properties={}
# id="Customer'S Information" type='Information' properties={}
# id='Error In The Process Of Moving The Studio Recently' type='Event' properties={}
# id='100 Megabit' type='Data rate' properties={}
# id="6 O'Clock Meeting" type='Event' properties={}
# id='Malware Incident' type='Event' properties={}
# id='Kt' type='Organization' properties={}
# id='June 2024' type='Date' properties={}
# id='Jtbc' type='Organization' properties={}
# id='600,000 Subscribers' type='Group' properties={}
# id='Torrent Protocol' type='Protocol' properties={}
# id='Malware' type='Software' properties={}
# id='Police Investigation' type='Event' properties={}
# id='Kt Corp' type='Organization' properties={}
# id='김영섭 후보' type='Person' properties={}
# id='Lee Suk-Chae' type='Person' properties={}
# id='Qook' type='Brand' properties={}
# id='Lee Seok-Chae' type='Person' properties={}
# id='Woori Bank' type='Organization' properties={}
# id='Busan Bank' type='Organization' properties={}
# id='Rwanda' type='Location' properties={}
# id='Epsilon' type='Organization' properties={}
# id='Microsoft' type='Organization' properties={}
# id='Samsung' type='Organization' properties={}
# id='Ericsson' type='Organization' properties={}
# id='Nokia' type='Organization' properties={}
# id='Alcatel Space' type='Organization' properties={}
# id='Asia Broadcast Satellite' type='Organization' properties={}
# id='Koreasat-3' type='Satellite' properties={}
# id='South Korea' type='Location' properties={}
# id='Skt' type='Organization' properties={}
# id='Sk-Kt Rivalry' type='Concept' properties={}
# id='Torrentfreak' type='Organization' properties={}
# id='Giga Lte' type='Concept' properties={}
# id='Kt' type='Organization' properties={}
# id='Samsung Electronics' type='Organization' properties={}
# id='Giga Lte' type='Technology' properties={}
# id='Wi-Fi' type='Technology' properties={}
# id='Lte' type='Technology' properties={}
# id='Tri-Band Lte-A' type='Technology' properties={}
# id='June 2015' type='Date' properties={}
# id='Korean Market' type='Location' properties={}
# id='Kt' type='Operator' properties={}
# id='T-On Telecom' type='Operator' properties={}
# id='South Korea' type='Location' properties={}
# id='Trs' type='Service' properties={}
# id='Kt' type='Organization' properties={}
# id='Kibot' type='Device' properties={}
# id='Smartphones' type='Device' properties={}
# ==============================
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id='East Telecom', type='Organization', properties={}) type='ACQUIRED_STAKE' properties={}
# source=Node(id='East Telecom', type='Organization', properties={}) target=Node(id='Uzbekistan', type='Country', properties={}) type='OPERATES_IN' properties={}
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id='Super Imax', type='Organization', properties={}) type='ACQUIRED_STAKE' properties={}
# source=Node(id='Kt Japan Co., Ltd.', type='Organization', properties={}) target=Node(id='Kt', type='Organization', properties={}) type='SUBSIDIARY_OF' properties={}
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id='Kt Japan Co., Ltd.', type='Organization', properties={}) type='PARENT_COMPANY_OF' properties={}
# source=Node(id='Kt Japan Co., Ltd.', type='Organization', properties={}) target=Node(id='International Network Infrastructure Business', type='Business operation', properties={}) type='ENGAGES_IN' properties={}
# source=Node(id='Kt Japan Co., Ltd.', type='Organization', properties={}) target=Node(id='Local Network Infrastructure Business', type='Business operation', properties={}) type='ENGAGES_IN' properties={}
# source=Node(id='Kt Japan Co., Ltd.', type='Organization', properties={}) target=Node(id='Data Center Business', type='Business operation', properties={}) type='ENGAGES_IN' properties={}
# source=Node(id='Data Center Business', type='Business operation', properties={}) target=Node(id='Housing', type='Business operation', properties={}) type='INCLUDES' properties={}
# source=Node(id='Kt Japan Co., Ltd.', type='Organization', properties={}) target=Node(id='Cloud Services', type='Business operation', properties={}) type='ENGAGES_IN' properties={}
# source=Node(id='Kt Japan Co., Ltd.', type='Organization', properties={}) target=Node(id='Roaming Business', type='Business operation', properties={}) type='ENGAGES_IN' properties={}
# source=Node(id='Kt Japan Co., Ltd.', type='Organization', properties={}) target=Node(id='Data Roaming Business', type='Business operation', properties={}) type='ENGAGES_IN' properties={}
# source=Node(id='Kt Japan Co., Ltd.', type='Organization', properties={}) target=Node(id='Sim Card Sales', type='Business operation', properties={}) type='ENGAGES_IN' properties={}
# source=Node(id='Kt Japan Co., Ltd.', type='Organization', properties={}) target=Node(id='Overseas Information And Communications Research', type='Business operation', properties={}) type='ENGAGES_IN' properties={}
# source=Node(id='Kt Sports', type='Organization', properties={}) target=Node(id='Kt Corporation', type='Organization', properties={}) type='SPONSORED_BY' properties={}
# source=Node(id='Kt Corporation', type='Organization', properties={}) target=Node(id='Ktf', type='Organization', properties={}) type='MERGED_WITH' properties={}
# source=Node(id='Kt Sports', type='Organization', properties={}) target=Node(id='Suwon', type='Place', properties={}) type='HEADQUARTERS_LOCATION' properties={}
# source=Node(id='Kt Sports', type='Organization', properties={}) target=Node(id='Baseball', type='Sport', properties={}) type='HAS_TEAM' properties={}
# source=Node(id='Kt Sports', type='Organization', properties={}) target=Node(id='Basketball', type='Sport', properties={}) type='HAS_TEAM' properties={}
# source=Node(id='Kt Sports', type='Organization', properties={}) target=Node(id='Esports', type='Sport', properties={}) type='SPONSORS_TEAM' properties={}
# source=Node(id='Suwon Kt Sonicboom', type='Sports team', properties={}) target=Node(id="Men'S Basketball", type='Sports category', properties={}) type='PARTICIPATES_IN' properties={}
# source=Node(id='Suwon Kt Sonicboom', type='Sports team', properties={}) target=Node(id='Suwon', type='Location', properties={}) type='BASED_IN' properties={}
# source=Node(id='Kt Wiz', type='Sports team', properties={}) target=Node(id='Baseball', type='Sports category', properties={}) type='PARTICIPATES_IN' properties={}
# source=Node(id='Kt Wiz', type='Sports team', properties={}) target=Node(id='Suwon', type='Location', properties={}) type='BASED_IN' properties={}
# source=Node(id='Kt Rolster', type='Sports team', properties={}) target=Node(id='Starcraft Ii', type='Sports category', properties={}) type='PARTICIPATES_IN' properties={}
# source=Node(id='Kt Rolster', type='Sports team', properties={}) target=Node(id='League Of Legends', type='Sports category', properties={}) type='PARTICIPATES_IN' properties={}
# source=Node(id='Kt Rolster', type='Sports team', properties={}) target=Node(id='Professional Gaming Teams', type='Category', properties={}) type='PARTICIPATES_IN' properties={}
# source=Node(id='Kt Rolster', type='Sports team', properties={}) target=Node(id='Seoul', type='Location', properties={}) type='BASED_IN' properties={}
# source=Node(id='Kt Shooting Team', type='Sports team', properties={}) target=Node(id='Sports Shooting', type='Sports category', properties={}) type='PARTICIPATES_IN' properties={}
# source=Node(id='Kt Shooting Team', type='Sports team', properties={}) target=Node(id='Hwaseong', type='Location', properties={}) type='BASED_IN' properties={}
# source=Node(id='Kt Hockey Team', type='Sports team', properties={}) target=Node(id="Women'S Field Hockey", type='Sports category', properties={}) type='PARTICIPATES_IN' properties={}
# source=Node(id='Kt Hockey Team', type='Sports team', properties={}) target=Node(id='Seongnam', type='Location', properties={}) type='BASED_IN' properties={}
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id='South Korea National Football Team', type='Organization', properties={}) type='SPONSOR' properties={}
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id='Lpga Of Korea Tour Golfers', type='Group', properties={}) type='SPONSOR' properties={}
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id='2002 Fifa World Cup', type='Event', properties={}) type='SPONSOR' properties={}
# source=Node(id='2002 Fifa World Cup', type='Event', properties={}) target=Node(id='Korea', type='Location', properties={}) type='HELD_IN' properties={}
# source=Node(id='2002 Fifa World Cup', type='Event', properties={}) target=Node(id='Japan', type='Location', properties={}) type='HELD_IN' properties={}
# source=Node(id='Kt Corporation', type='Organization', properties={}) target=Node(id='Sk Telecom', type='Organization', properties={}) type='RIVALRY' properties={}
# source=Node(id='Kt Corporation', type='Organization', properties={}) target=Node(id='Telecommunications Derby', type='Event', properties={}) type='PARTICIPANT' properties={}
# source=Node(id='Sk Telecom', type='Organization', properties={}) target=Node(id='Telecommunications Derby', type='Event', properties={}) type='PARTICIPANT' properties={}
# source=Node(id='Telecommunications Derby', type='Event', properties={}) target=Node(id='Esports', type='Activity', properties={}) type='CONTESTED_IN' properties={}
# source=Node(id='Telecommunications Derby', type='Event', properties={}) target=Node(id="Men'S Basketball", type='Activity', properties={}) type='CONTESTED_IN' properties={}
# source=Node(id='Sk Wyverns', type='Organization', properties={}) target=Node(id='Kt Wiz', type='Organization', properties={}) type='RIVALRY' properties={}
# source=Node(id='Sk Wyverns', type='Organization', properties={}) target=Node(id='Telecommunications Derby', type='Event', properties={}) type='PARTICIPANT' properties={}
# source=Node(id='Kt Wiz', type='Organization', properties={}) target=Node(id='Telecommunications Derby', type='Event', properties={}) type='PARTICIPANT' properties={}
# source=Node(id='Jeju Smart Place Test Bed Project', type='Project', properties={}) target=Node(id="Korea'S Ministry Of Trade, Industry And Energy", type='Organization', properties={}) type='LED_BY' properties={}
# source=Node(id='Jeju Smart Place Test Bed Project', type='Project', properties={}) target=Node(id="6,000 Households In Jeju Island'S Gujwa-Eup Area", type='Location', properties={}) type='LOCATED_IN' properties={}
# source=Node(id='Jeju Smart Place Test Bed Project', type='Project', properties={}) target=Node(id='May 2009', type='Date', properties={}) type='START_DATE' properties={}
# source=Node(id='Jeju Smart Place Test Bed Project', type='Project', properties={}) target=Node(id='May 2013', type='Date', properties={}) type='END_DATE' properties={}
# source=Node(id='Jeju Smart Place Test Bed Project', type='Project', properties={}) target=Node(id='Integrated Energy Management Service', type='Concept', properties={}) type='AIMED_TO_PROVIDE' properties={}
# source=Node(id='Jeju Smart Place Test Bed Project', type='Project', properties={}) target=Node(id='Efficient Energy Usage', type='Concept', properties={}) type='AIMED_TO_ACHIEVE' properties={}
# source=Node(id='Efficient Energy Usage', type='Concept', properties={}) target=Node(id='Renewable Energy Sources', type='Concept', properties={}) type='BY_ADOPTING' properties={}
# source=Node(id='Efficient Energy Usage', type='Concept', properties={}) target=Node(id='Energy Storage Devices', type='Concept', properties={}) type='BY_ADOPTING' properties={}
# source=Node(id='Jeju Smart Place Test Bed Project', type='Project', properties={}) target=Node(id='Kt Consortium', type='Organization', properties={}) type='EXECUTED_BY' properties={}
# source=Node(id='Kt Consortium', type='Organization', properties={}) target=Node(id='Kt', type='Organization', properties={}) type='INCLUDES' properties={}
# source=Node(id='Kt Consortium', type='Organization', properties={}) target=Node(id='Samsung Sdi', type='Organization', properties={}) type='INCLUDES' properties={}
# source=Node(id='Kt Consortium', type='Organization', properties={}) target=Node(id='Hyosung', type='Organization', properties={}) type='INCLUDES' properties={}
# source=Node(id='Kt Consortium', type='Organization', properties={}) target=Node(id='Samsung Electronics', type='Organization', properties={}) type='INCLUDES' properties={}
# source=Node(id='10-Gigabit Internet Plan', type='Concept', properties={}) target=Node(id='Youtuber It-Seop', type='Person', properties={}) type='USED_BY' properties={}
# source=Node(id='10-Gigabit Internet Plan', type='Concept', properties={}) target=Node(id='100 Megabit', type='Concept', properties={}) type='SERVICED_AT_SPEED' properties={}
# source=Node(id='Youtuber It-Seop', type='Person', properties={}) target=Node(id='Speed Test Data', type='Concept', properties={}) type='RELEASED' properties={}
# source=Node(id='Speed Test Data', type='Concept', properties={}) target=Node(id='Video', type='Concept', properties={}) type='IN' properties={}
# source=Node(id='Speed Test Data', type='Concept', properties={}) target=Node(id='Controversy', type='Concept', properties={}) type='AFTER_WHICH' properties={}
# source=Node(id='Controversy', type='Concept', properties={}) target=Node(id='Kt Users', type='Group', properties={}) type='REPELLED_BY' properties={}
# source=Node(id='April 17, 2021', type='Date', properties={}) target=Node(id='10-Gigabit Internet Plan', type='Concept', properties={}) type='REVEALED_ON' properties={}
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id="Customer'S Information", type='Information', properties={}) type='EXPLAINED' properties={}
# source=Node(id='Error In The Process Of Moving The Studio Recently', type='Event', properties={}) target=Node(id="Customer'S Information", type='Information', properties={}) type='CAUSES_ERROR_IN_TRANSFER_OF' properties={}
# source=Node(id="Customer'S Information", type='Information', properties={}) target=Node(id='100 Megabit', type='Data rate', properties={}) type='RESULTS_IN' properties={}
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id="6 O'Clock Meeting", type='Event', properties={}) type='HELD' properties={}
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id='Customers', type='Person', properties={}) type='APOLOGIZED_TO' properties={}
# source=Node(id='Jtbc', type='Organization', properties={}) target=Node(id='Kt', type='Organization', properties={}) type='INVESTIGATION_REVEALED' properties={}
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id='600,000 Subscribers', type='Group', properties={}) type='REMOTELY_INSTALLED_MALWARE' properties={}
# source=Node(id='Malware', type='Software', properties={}) target=Node(id='600,000 Subscribers', type='Group', properties={}) type='INSTALLED_ON' properties={}
# source=Node(id='Malware', type='Software', properties={}) target=Node(id='Torrent Protocol', type='Protocol', properties={}) type='THROTTLE_DISRUPT_MONITOR_USAGE_OF' properties={}
# source=Node(id='Police Investigation', type='Event', properties={}) target=Node(id='Kt', type='Organization', properties={}) type='INVESTIGATION_ONGOING_ON' properties={}
# source=Node(id='김영섭 후보', type='Person', properties={}) target=Node(id='Kt Corp', type='Organization', properties={}) type='CEO' properties={}
# source=Node(id='Kt Corp', type='Organization', properties={}) target=Node(id='Qook', type='Brand', properties={}) type='BRAND' properties={}
# source=Node(id='Lee Suk-Chae', type='Person', properties={}) target=Node(id='Kt Corp', type='Organization', properties={}) type='PERSONNEL' properties={}
# source=Node(id='Kt Corp', type='Organization', properties={}) target=Node(id='Woori Bank', type='Organization', properties={}) type='AGREEMENT' properties={}
# source=Node(id='Kt Corp', type='Organization', properties={}) target=Node(id='Busan Bank', type='Organization', properties={}) type='AGREEMENT' properties={}
# source=Node(id='Kt Corp', type='Organization', properties={}) target=Node(id='Rwanda', type='Location', properties={}) type='AGREEMENT' properties={}
# source=Node(id='Kt Corp', type='Organization', properties={}) target=Node(id='Epsilon', type='Organization', properties={}) type='ACQUISITION' properties={}
# source=Node(id='Kt Corp', type='Organization', properties={}) target=Node(id='Microsoft', type='Organization', properties={}) type='NETWORK_INFRASTRUCTURE_SUPPLIER' properties={}
# source=Node(id='Kt Corp', type='Organization', properties={}) target=Node(id='Samsung', type='Organization', properties={}) type='COLLABORATION' properties={}
# source=Node(id='Kt Corp', type='Organization', properties={}) target=Node(id='Ericsson', type='Organization', properties={}) type='5G_CONTRACT' properties={}
# source=Node(id='Kt Corp', type='Organization', properties={}) target=Node(id='Nokia', type='Organization', properties={}) type='5G_TRIALS' properties={}
# source=Node(id='Alcatel Space', type='Organization', properties={}) target=Node(id='Satellite', type='Satellite', properties={}) type='ACQUISITION' properties={}
# source=Node(id='South Korea', type='Location', properties={}) target=Node(id='Kt Corp', type='Organization', properties={}) type='LOCATION' properties={}
# source=Node(id='Skt', type='Organization', properties={}) target=Node(id='Sk-Kt Rivalry', type='Concept', properties={}) type='PARTICIPANT' properties={}
# source=Node(id='Kt Corp', type='Organization', properties={}) target=Node(id='Sk-Kt Rivalry', type='Concept', properties={}) type='PARTICIPANT' properties={}
# source=Node(id='Kt Corp', type='Organization', properties={}) target=Node(id='Torrentfreak', type='Organization', properties={}) type='REPORTER' properties={}
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id='Samsung Electronics', type='Organization', properties={}) type='COLLABORATION' properties={}
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id='Giga Lte', type='Technology', properties={}) type='LAUNCH' properties={}
# source=Node(id='Giga Lte', type='Technology', properties={}) target=Node(id='Wi-Fi', type='Technology', properties={}) type='COMBINE_WITH' properties={}
# source=Node(id='Giga Lte', type='Technology', properties={}) target=Node(id='Lte', type='Technology', properties={}) type='COMBINE_WITH' properties={}
# source=Node(id='Giga Lte', type='Technology', properties={}) target=Node(id='Lte', type='Technology', properties={}) type='FASTER_THAN' properties={}
# source=Node(id='Giga Lte', type='Technology', properties={}) target=Node(id='Tri-Band Lte-A', type='Technology', properties={}) type='FASTER_THAN' properties={}
# source=Node(id='Tri-Band Lte-A', type='Technology', properties={}) target=Node(id='Korean Market', type='Location', properties={}) type='AVAILABLE_IN' properties={}
# source=Node(id='Giga Lte', type='Technology', properties={}) target=Node(id='June 2015', type='Date', properties={}) type='ANNOUNCED_IN' properties={}
# source=Node(id='Kt', type='Operator', properties={}) target=Node(id='Trs', type='Service', properties={}) type='PROVIDES' properties={}
# source=Node(id='Kt', type='Operator', properties={}) target=Node(id='T-On Telecom', type='Operator', properties={}) type='MERGED' properties={}
# source=Node(id='T-On Telecom', type='Operator', properties={}) target=Node(id='South Korea', type='Location', properties={}) type='LOCATED_IN' properties={}
# source=Node(id='Kt', type='Operator', properties={}) target=Node(id='South Korea', type='Location', properties={}) type='LOCATED_IN' properties={}
# source=Node(id='Kt', type='Organization', properties={}) target=Node(id='Kibot', type='Device', properties={}) type='LAUNCHED' properties={}
# source=Node(id='Kibot', type='Device', properties={}) target=Node(id='Smartphones', type='Device', properties={}) type='FEATURES_FOUND_ON' properties={}

# %%
graph = NetworkxEntityGraph()
node_types = set()
edge_types = set()

def to_id(x):
    return getattr(x, "id", x)

for gd in all_graph_docs:
    # 노드
    for n in gd.nodes:
        nid = str(to_id(n))
        graph.add_node(nid)
        node_types.add(n.type)
    # 엣지
    for r in gd.relationships:
        src = str(to_id(r.source))
        tgt = str(to_id(r.target))
        rel = getattr(r, "type", "RELATED_TO")
        graph._graph.add_edge(src, tgt, relation=rel)
        edge_types.add(r.type)

graph._graph = graph._graph.to_undirected()

print(f"[info] 노드 수: {len(graph._graph.nodes)}, 엣지 수: {len(graph._graph.edges)}")
print(f"[info] 노드 타입 수: {len(node_types)}, 엣지 타입 수: {len(edge_types)}")
print(f"노드 종류 : {list(node_types)[:30]}")
print(f"엣지 종류 : {list(edge_types)[:30]}")
# Out:
# [info] 노드 수: 4087, 엣지 수: 3758
# [info] 노드 타입 수: 189, 엣지 타입 수: 1160
# 노드 종류 : ['Sports event', 'List', 'Total assets', 'Virtual mvpd', 'Program', 'Measurement unit', 'Application', 'Servicetype', 'Patent', 'Cable', 'Stocksharetype', 'Value', 'Time', 'Tool', 'Website', 'Pagecollection', 'Technology', 'Major1', 'Business group', 'Asn', 'Radio interface', 'License', 'Alias', 'Event', 'Company type', 'Other', 'Agreement', 'Problem', 'Slogan', 'Isp']
# 엣지 종류 : ['RESULTED_IN_BREAKUP_OF', 'OPERATES_LONG_DISTANCE_LINES_AS_SUBSIDIARY', 'ALSOKNOWNAS', 'REDIRECTS_TO', 'LINKED_TO', 'HOLDING_COMPANY_OF', 'ACQUIREDIN1994BY', 'HAS_SUBPROTOCOL', 'STARTED_PROVIDING_AT', 'PLANNED_ISP', 'ALTERED_POLICY', 'HANDED_OVER_DATA_TO', 'HAS_3G_CDMA2000_SUBSCRIBERS', 'CONTRACT_WITH', 'NOT_PREVALENT_IN', 'IN_COLLABORATION_WITH', 'HAS_PRESIDENT', 'ASKS', 'WRITES_FOR', 'REPORTED_ABOUT', 'BUYER', 'HAS_EQUITY_INTEREST_IN', 'SINCE', 'PARENT', 'FOUNDED_BY', 'RANKED_AFTER', 'CEO', 'ENTERED_PARTNERSHIP_WITH', 'START_SALE_DATE', 'AFFILIATED_WITH']

# %%
graph_chain = GraphQAChain.from_llm(
    llm=llm,
    graph=graph,
    verbose=True,
)

print(graph_chain.invoke({"query": "Kt의 창립일은 언제야?"})["result"])
# Out:
# > Entering new GraphQAChain chain...
# Entities Extracted:
# NONE
# Full Context:
#
#
# > Finished chain.
# 저는 해당 정보가 없습니다.

# %% [markdown]
# 아래는 graph chain의 내부에 있는 프롬프트를 복사한 것입니다.
# 해당 프롬프트를 보면 어떻게 동작하는지, 어떤 한계가 있는지 생각해 볼 수 있습니다.
#
# 이 기본 프롬프트를 사용하는게 아니라 약간 개선하여 그래프 RAG의 성능을 높여봅시다.
#
#
# ```python
# qa_prompt:   = PromptTemplate(input_variables=['context', 'question'],
#                 input_types={}, partial_variables={},
#                 template="""Use the following knowledge triplets to answer the question at the end.
#                 If you don't know the answer, just say that you don't know, don't try to make up an answer.
#                 \n\n{context}\n\nQuestion: {question}\nHelpful Answer:""")
#
# entity_prompt: = PromptTemplate(input_variables=['input'],
#                                 input_types={}, partial_variables={},
#                                 template="""Extract all entities from the following text. As a guideline, a proper noun is generally capitalized.
#                                 You should definitely extract all names and places.\n\nReturn the output as a single comma-separated list, or NONE if there is nothing of note to return.
#                                 \n\nEXAMPLE\ni'm trying to improve Langchain's interfaces, the UX, its integrations with various products the user might want ... a lot of stuff.
#                                 \nOutput: Langchain\nEND OF EXAMPLE\n\nEXAMPLE\ni'm trying to improve Langchain's interfaces, the UX, its integrations
#                                 with various products the user might want ... a lot of stuff.
#                                 I'm working with Sam.\nOutput: Langchain, Sam\nEND OF EXAMPLE\n\nBegin!\n\n{input}\nOutput:"""),
# ```

# %%
from langchain.prompts import PromptTemplate

candidate_entities = list(graph._graph.nodes)

ENTITY_PROMPT_KO = PromptTemplate(
    input_variables=["input", "entities"],
    template="""다음 질문에 답하려면 아래 '그래프 엔티티 후보' 중에서 관련된 엔티티 이름을 1~5개 고르세요.
- 정확히 '엔티티 이름'만 쉼표로 출력하세요.
- 후보에 없으면 고르지 마세요.

[그래프 엔티티 후보]
{entities}

[질문]
{input}

[정답](쉼표로 구분된 엔티티들만):"""
)

QA_PROMPT_KO = PromptTemplate(
    input_variables=["question", "context"],
    template="""당신은 지식그래프 QA 어시스턴트입니다.
주어진 엔티티 주변 트리플을 근거로 한국어로 간결하게 답하세요.
관련 근거의 레퍼런스를 트리플 형태로 같이 제시하세요.
그래프와 컨텍스트에서 찾을 수 없다면 관련 근거가 없다고 말하세요.

형식 : [node1] → [edge] → [node2]

[질문]
{question}

[컨텍스트]
{context}

[답변]"""
)

graph_chain = GraphQAChain.from_llm(
    llm=llm,
    graph=graph,
    entity_prompt=ENTITY_PROMPT_KO.partial(entities="\n".join(map(str, candidate_entities))),
    qa_prompt=QA_PROMPT_KO,
    verbose=True,
)

# %%
print(graph_chain.invoke({"query": "케이티의 창립일은 언제야?"})["result"])
# Out:
# > Entering new GraphQAChain chain...
# Entities Extracted:
# Kt,Kt Corporation,Kt Corp,Kt Group
# Full Context:
# Kt ACQUIRED_STAKE East Telecom
# Kt ACQUIRED_STAKE Super Imax
# Kt SUBSIDIARY_OF Kt Japan Co., Ltd.
# Kt SPONSOR South Korea National Football Team
# Kt SPONSOR Lpga Of Korea Tour Golfers
# Kt SPONSOR 2002 Fifa World Cup
# Kt EXPLAINED Customer'S Information
# Kt HELD 6 O'Clock Meeting
# Kt APOLOGIZED_TO Customers
# Kt REMOTELY_INSTALLED_MALWARE 600,000 Subscribers
# Kt SIGNED_DEAL_WITH Samsung Electronics
# Kt LAUNCH Giga Lte
# Kt PROVIDES Trs
# Kt MERGED T-On Telecom
# Kt OPERATES_IN South Korea
# Kt LAUNCHED Kibot
# Kt LAUNCHED Mobile Tv App
# Kt OPERATES Koreasat Fleet Of Satellites
# Kt ANNOUNCED_LAUNCH Giga Island
# Kt PARTNERSHIP_WITH Bangladesh Government
# Kt PARTNERSHIP_WITH International Organizations
# Kt PARTNERSHIP_WITH Public Institutions
# Kt PARTNERSHIP_WITH Non-Governmental Organizations
# Kt CONNECTED_TO Moheshkhali Island
# Kt INSTALLED_TECHNOLOGY_AT Giga Microwave
# Kt USED_TECHNOLOGY_AT Giga Wires
# Kt CONTRACT_WITH Brunei
# Kt ESTABLISH National Data Center
# Kt MAJOR_SHAREHOLDER Mongolia Telecom
# Kt OPERATED_TRAINING_PROGRAMS_IN Mongolia
# Kt CONTRACTED_WITH Mongolian Government
# Kt ESTABLISHED Earthquake Disaster Warning System
# Kt SIGNED_CONSULTANCY_AGREEMENT Telkom
# Kt OPERATES_IN South Africa
# Kt SIGNED_CONTRACT_TO_BUILD Mobile Wimax Network
# Kt SIGNED_DEAL_TO_BUILD Telecommunication Network Backbone
# Kt CONDUCTED National Information Security Project
# Kt SIGNED_CONTRACT_TO_BUILD Joint Venture To Build Nationwide Mobile Lte Network
# Kt SIGNATORY $18 Million Contract
# Kt SIGNATORY $130 Million Broadband Project
# Kt ENTERED_PARTNERSHIP_WITH Public Private Partnership
# Kt AGREEMENT Boston
# Kt PARTICIPATE_IN Boston Digital Equity Project
# Kt PROVIDE Giga Wire Technology
# Kt SOLD Korea Mobile Telecom
# Kt MERGED_WITH Ktf
# Kt RELAUNCHED_INTERNET_SERVICES Olleh
# Kt LAUNCH_DATE January 2011
# Kt FOUNDED_IN_YEAR 1981
# Kt OPERATES_IN Korea
# Kt ALONG_WITH_ISP Lg Dacom
# Kt ACQUIRED Thrunet
# Kt INTRODUCED Apple Iphone
# Kt LAUNCHED_SLOGAN Let'S
# Kt CUT_WORKFORCE_IN Workforce Cut October 1 2003
# Kt REPORTED_IN First Quarterly Loss October 31 2003
# Kt OPENED_BRANCH_IN North Korea Gaesung Branch
# Kt HAS_SLOGAN Olleh Management
# Kt HAS_CI Olleh Kt
# Kt LAUNCHED Qook
# Kt LAUNCHED Show
# Kt LAUNCHED_IN_MARKET Apple'S Iphone
# Kt LAUNCHED Show Omnia
# Kt LAUNCHED Ucloud
# Kt INCLUDED_IN_INDEX Dow Jones Sustainability World Index
# Kt LAUNCHED_IN_MARKET Apple'S Iphone 4
# Kt SERVICE_PROVIDER_FOR G20 Seoul Summit
# Kt RENAMED_FROM Olleh Home
# Kt RENAMED_FROM Olleh Mobile
# Kt ACQUIRED_STAKE_IN Bc Card
# Kt LAUNCHED Kt Lte Service
# Kt AWARDED_BY Dow Jones Sustainability Indexes
# Kt STRENGTHENED_BUSINESS_RELATIONSHIP_WITH Docomo
# Kt ANNOUNCED_AGREEMENT_WITH Rwandan Government
# Kt ESTABLISHED_JOINT_VENTURE_WITH Rwanda Olleh Services Ltd
# Kt HAS_PRESIDENT Suk-Jae Lee
# Kt PLANNED_TO_PROVIDE_AT_EVENT 5G Services
# Kt PLANNED_TO_PROVIDE_SERVICE_AT 2018 Winter Olympics
# Kt OPENED Wi-Fi Hotspots
# Kt PARTNERED_WITH Samsung
# Kt PARTNERED_WITH Posco
# Kt PARTNERED_WITH Hyundai Mobis
# Kt PARTNERED_WITH Intel
# Kt SIGNED_CONTRACT_WITH Ericsson
# Kt PARTNERED_WITH Nvidia
# Kt LAUNCHED 5G Open Lab
# Kt COMMERCIALIZED Broadband Internet Service
# Kt SIGNED_MOU_WITH Nokia
# Kt TESTED 5G Technologies
# Kt SIGNED_CONTRACT_WITH Kt And Ericsson 5G Commercial Contract
# Kt SUPPLIED_BY Public Safety Network Solutions
# Kt SCHOOL_DIVISION Satellite-Operating Division
# Kt COMMERCIALIZED 5G Standalone Technology
# Kt ACQUIRED Epsilon Telecommunications
# Kt SUPPLIED_NETWORK_INFRASTRUCTURE_TO Microsoft
# Kt PROVIDES Wireless Service
# Kt HAS_DATE 2012
# Kt OWNS_AND_OPERATES Wi-Fi Hotspot
# Kt OPERATES_UNDER_NAME Kt Olleh Wifi Zones
# Kt DISCONTINUED 2G Coverage
# Kt IS_A South Korean Mobile Network Operator
# Kt MEMBER_OF Conexus Mobile Alliance
# Kt PART_OF Largest Conglomerates In South Korea
# Kt BELONGS_TO Communication Service
# Kt INCLUDES Kt Consortium
# Kt INVESTIGATION_REVEALED Jtbc
# Kt INVESTIGATION_ONGOING_ON Police Investigation
# Kt CONTRACT_WITH Alcatel Space
# Kt LARGEST_SHAREHOLDER National Pension Service
# Kt RENAMED_TO Korea Telecom
# Kt PLANNED_FOR Privatization Plans
# Kt ANNIVERSARY_OF 20Th Anniversary
# Kt PRIVATIZED Privatization Finalized 2002
# Kt IS_CORPORATE_GROUP_OF Kt Corporate Group 2005
# Kt INVOLVES_COMPANY Kt-Ktf Merger Plans January 2009
# Kt INVOLVES_COMPANY Kt-Ktf Merger Approval March 2009
# Kt Corporation SPONSORED_BY Kt Sports
# Kt Corporation MERGED_WITH Ktf
# Kt Corporation RIVALRY Sk Telecom
# Kt Corporation PARTICIPANT Telecommunications Derby
# Kt Corporation PROVIDES_SATELLITE_SERVICES Koreasat Fleet Of Satellites
# Kt Corporation FORMERLY_KNOWN_AS Korea Telecommunications Authority
# Kt Corporation CEO Kim Young-Shub
# Kt Corporation OWNER Hyundai Motor Group
# Kt Corporation OWNER Government Of South Korea
# Kt Corporation OWNER Shinhan Bank
# Kt Corporation HAS_SUBSIDIARY Ktds
# Kt Corporation HAS_SUBSIDIARY Kth
# Kt Corporation HAS_SUBSIDIARY Ktp
# Kt Corporation HAS_SUBSIDIARY Ktn
# Kt Corporation HAS_SUBSIDIARY Kt Submarine
# Kt Corporation HAS_SUBSIDIARY Kt Telecop
# Kt Corporation HAS_SUBSIDIARY Kt Capital
# Kt Corporation HAS_SUBSIDIARY Kt Rental
# Kt Corporation HAS_SUBSIDIARY Ktm&S
# Kt Corporation AFFILIATE Genie Music
# Kt Corporation HAS_SUBSIDIARY Kt Studio Genie
# Kt Corporation HAS_SUBSIDIARY Nasmedia
# Kt Corporation HAS_SUBSIDIARY Kt Cs
# Kt Corporation HAS_SUBSIDIARY Kt Is
# Kt Corporation AFFILIATE Kt Skylife
# Kt Corporation HAS_SUBSIDIARY Kt Wibro Infra
# Kt Corporation HEADQUARTERS Seongnam
# Kt Corporation FOUNDED_IN Seoul
# Kt Corporation AFFILIATE Bc Card
# Kt Corporation AFFILIATE K Bank
# Kt Corporation AFFILIATE Skytv
# Kt Corporation AFFILIATE Tving
# Kt Corporation INVOLVES Kt Internet Slowdown Incident
# Kt Corporation INVOLVES Malware Incident
# Kt Corporation ABOUT This Article
# Kt Corp BRAND Qook
# Kt Corp AGREEMENT Woori Bank
# Kt Corp AGREEMENT Busan Bank
# Kt Corp AGREEMENT Rwanda
# Kt Corp ACQUISITION Epsilon
# Kt Corp NETWORK_INFRASTRUCTURE_SUPPLIER Microsoft
# Kt Corp COLLABORATION Samsung
# Kt Corp 5G_CONTRACT Ericsson
# Kt Corp 5G_TRIALS Nokia
# Kt Corp PARTICIPANT Sk-Kt Rivalry
# Kt Corp REPORTER Torrentfreak
# Kt Corp INTRODUCED Iphone
# Kt Corp INTRODUCED_DATE November 2009
# Kt Corp LAUNCHED Ipad
# Kt Corp LAUNCHED_DATE November 2010
# Kt Corp CEO 김영섭 후보
# Kt Corp PERSONNEL Lee Suk-Chae
# Kt Corp LOCATION South Korea
# Kt Group ESTABLISHED_IN 1981
# Kt Group LISTED_ON Korea Exchange
# Kt Group LISTED_ON London Stock Exchange
# Kt Group LISTED_ON New York Stock Exchange
# Kt Group OPERATES_IN South Korea
# Kt Group PART_OF Kospi 200
#
# > Finished chain.
# 케이티(Kt)의 창립일은 1981년입니다.
#
# 근거:
# Kt FOUNDED_IN_YEAR 1981

# %%
graph_chain.verbose = False

query_list = [
    "Kt의 주요 사업은 뭐야?",
    "Kt는 어디에 위치해 있어?",
    "2009년에 각 통신사들에는 어떤 일이 있었어?",
    "미국의 통신사는 어떤 곳이 있어?",
    "일본의 두 통신사를 비교해줘",
    ""
]

for idx, query in enumerate(query_list):
    print(f"{idx+1}. [{query}]")
    print(f"답변 : {graph_chain.invoke({'query': query})['result']}")
    print("-"*100)
# Out:
# 1. [Kt의 주요 사업은 뭐야?]
# 답변 : Kt의 주요 사업은 국제 네트워크 인프라, 지역 네트워크 인프라, 데이터 센터, 클라우드 서비스, 로밍 사업입니다.
#
# 근거:
# International Network Infrastructure Business ENGAGES_IN Kt Japan Co., Ltd.
# Local Network Infrastructure Business ENGAGES_IN Kt Japan Co., Ltd.
# Data Center Business ENGAGES_IN Kt Japan Co., Ltd.
# Cloud Services ENGAGES_IN Kt Japan Co., Ltd.
# Roaming Business ENGAGES_IN Kt Japan Co., Ltd.
# ----------------------------------------------------------------------------------------------------
# 2. [Kt는 어디에 위치해 있어?]
# 답변 : Kt Corporation의 본사는 성남시에 위치해 있습니다.
#
# 근거:
# Kt Corporation → HEADQUARTERS → Seongnam
# ----------------------------------------------------------------------------------------------------
# 3. [2009년에 각 통신사들에는 어떤 일이 있었어?]
# 답변 : 2009년에 주요 통신사 Kt와 Ktf는 합병 계획을 발표하고 3월에는 방송통신위원회 승인을 받아 합병을 완료했습니다.
#
# 근거:
# Kt-Ktf Merger Plans January 2009 → ANNOUNCED → Suk-Chae Lee
# Kt-Ktf Merger Plans January 2009 → INVOLVES_COMPANY → Kt
# Kt-Ktf Merger Plans January 2009 → INVOLVES_COMPANY → Kt Freetel
# Kt-Ktf Merger Approval March 2009 → APPROVED_BY → Korea Communications Commission
# Kt-Ktf Merger Approval March 2009 → INVOLVES_COMPANY → Kt
# Kt-Ktf Merger Approval March 2009 → INVOLVES_COMPANY → Kt Freetel
# Ktf → MERGED_WITH → Kt
# Ktf → MERGED_WITH → Kt Corporation
# ----------------------------------------------------------------------------------------------------
# 4. [미국의 통신사는 어떤 곳이 있어?]
# 답변 : 미국의 통신사로는 At&T가 있습니다.
#
# 근거:
# At&T → TELECOMMUNICATIONS_COMPANY_OF → United States
# At&T → LARGEST_PROVIDER_IN_UNITED_STATES → Mobile Telephone Services
# At&T → LARGEST_PROVIDER_IN_UNITED_STATES → Fixed Telephone Services
# At&T → HAS_UNIT → At&T Mobility
# ----------------------------------------------------------------------------------------------------
# 5. [일본의 두 통신사를 비교해줘]
# 답변 : 일본의 두 주요 통신사는 Ntt와 Kddi입니다.
# - Ntt는 정부 소유로 출발해 Ntt East, Ntt West, Ntt Communications 등을 보유한 지주회사이며, 광대역 광섬유, 유선 전화망을 운영합니다.
# - Kddi는 Au 브랜드로 서비스를 제공하며, 일본 내 Kddi Corporation에서 운영됩니다.
#
# 근거:
# Japan OWN Ntt
# Japan OPERATES_IN Kddi Corporation
# Japan OPERATES_IN Au By Kddi
# Ntt ESTABLISHED_AS Government-Owned Corporation
# Ntt OWN Broadband Fibre Connections
# Ntt OWN Landlines In Japan
# Ntt HOLDING_COMPANY Ntt East
# Ntt HOLDING_COMPANY Ntt West
# ----------------------------------------------------------------------------------------------------
# 6. [모든 통신사들 중에서 가입자가 가장 많은 통신사는?]
# 답변 : 관련 컨텍스트에서 "모든 통신사들 중 가입자가 가장 많은 통신사"에 관한 정보가 없습니다.
#
# 답변 근거: 관련 근거가 없음
# ----------------------------------------------------------------------------------------------------
